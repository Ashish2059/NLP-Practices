# %%
import nltk
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')

from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.

# %%
paragraph = """Nepal, country of Asia, lying along the southern slopes of the Himalayan mountain ranges. It is a landlocked country located between India to the east, 
south, and west and the Tibet Autonomous Region of China to the north. Its territory extends roughly 500 miles (800 kilometres) from east to west and 90 to 150 miles from 
north to south. The capital is Kathmandu.
Nepal, long under the rule of hereditary prime ministers favouring a policy of isolation, remained closed to the outside world until a palace revolt in 1950 restored the 
crown’s authority in 1951; the country gained admission to the United Nations in 1955. In 1991 the kingdom established a multiparty parliamentary system. In 2008, however, 
after a decadelong period of violence and turbulent negotiation with a strong Maoist insurgency, the monarchy was dissolved, and Nepal was declared a democratic republic.
Wedged between two giants, India and China, Nepal seeks to keep a balance between the two countries in its foreign policy—and thus to remain independent. A factor that 
contributes immensely to the geopolitical importance of the country is the fact that a strong Nepal can deny China access to the rich Gangetic Plain; Nepal thus marks the 
southern boundary of the Chinese sphere north of the Himalayas in Asia. """

# %%
sentences = nltk.sent_tokenize(paragraph)
print(sentences)
# Out:
# ['Nepal, country of Asia, lying along the southern slopes of the Himalayan mountain ranges.', 'It is a landlocked country located between India to the east, \nsouth, and west and the Tibet Autonomous Region of China to the north.', 'Its territory extends roughly 500 miles (800 kilometres) from east to west and 90 to 150 miles from \nnorth to south.', 'The capital is Kathmandu.', 'Nepal, long under the rule of hereditary prime ministers favouring a policy of isolation, remained closed to the outside world until a palace revolt in 1950 restored the \ncrown’s authority in 1951; the country gained admission to the United Nations in 1955.', 'In 1991 the kingdom established a multiparty parliamentary system.', 'In 2008, however, \nafter a decadelong period of violence and turbulent negotiation with a strong Maoist insurgency, the monarchy was dissolved, and Nepal was declared a democratic republic.', 'Wedged between two giants, India and China, Nepal seeks to keep a balance between the two
# ...

# %%
print("\n\n Result after Stemming \n\n")
stemmer = nltk.PorterStemmer()
# Stemming
for i in range(len(sentences)):
    words = nltk.word_tokenize(sentences[i])
    print(words)
    for word in words:
      print(word, "|", stemmer.stem(word))
# Out:
#  Result after Stemming
#
#
# ['Nepal', ',', 'country', 'of', 'Asia', ',', 'lying', 'along', 'the', 'southern', 'slopes', 'of', 'the', 'Himalayan', 'mountain', 'ranges', '.']
# Nepal | nepal
# , | ,
# country | countri
# of | of
# Asia | asia
# , | ,
# lying | lie
# along | along
# the | the
# southern | southern
# slopes | slope
# of | of
# the | the
# Himalayan | himalayan
# mountain | mountain
# ranges | rang
# . | .
# ['It', 'is', 'a', 'landlocked', 'country', 'located', 'between', 'India', 'to', 'the', 'east', ',', 'south', ',', 'and', 'west', 'and', 'the', 'Tibet', 'Autonomous', 'Region', 'of', 'China', 'to', 'the', 'north', '.']
# It | it
# is | is
# a | a
# landlocked | landlock
# country | countri
# located | locat
# between | between
# India | india
# to | to
# the | the
# east | east
# , | ,
# south | south
# , | ,
# and | and
# west | west
# and | and
# the | the
# Tibet | tibet
# Autonomous | autonom
# Region | region
# of | of
# China | china
# to | to
# the | the
# ...

# %%
nltk.pos_tag(words)
# Out:
# [('A', 'DT'),
#  ('factor', 'NN'),
#  ('that', 'WDT'),
#  ('contributes', 'VBZ'),
#  ('immensely', 'RB'),
#  ('to', 'TO'),
#  ('the', 'DT'),
#  ('geopolitical', 'JJ'),
#  ('importance', 'NN'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('country', 'NN'),
#  ('is', 'VBZ'),
#  ('the', 'DT'),
#  ('fact', 'NN'),
#  ('that', 'IN'),
#  ('a', 'DT'),
#  ('strong', 'JJ'),
#  ('Nepal', 'NNP'),
#  ('can', 'MD'),
#  ('deny', 'VB'),
#  ('China', 'NNP'),
#  ('access', 'NN'),
#  ('to', 'TO'),
#  ('the', 'DT'),
#  ('rich', 'JJ'),
#  ('Gangetic', 'NNP'),
#  ('Plain', 'NNP'),
#  (';', ':'),
#  ('Nepal', 'NNP'),
#  ('thus', 'RB'),
#  ('marks', 'VBZ'),
#  ('the', 'DT'),
#  ('southern', 'JJ'),
#  ('boundary', 'NN'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('Chinese', 'NNP'),
#  ('sphere', 'JJ'),
#  ('north', 'NN'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('Himalayas', 'NNP'),
#  ('in', 'IN'),
#  ('Asia', 'NNP'),
#  ('.', '.')]

# %%
import spacy

# %%
nlp=spacy.load("en_core_web_sm")
#doc=nlp("eating eats ate eaten proves doing did done what better proven")
doc=nlp(paragraph)
for x in doc:
  print(x, '-', x.lemma_, '-', x.lemma)
# Out:
# Nepal - Nepal - 13882040618093880941
# , - , - 2593208677638477497
# country - country - 12290671265767728302
# of - of - 886050111519832510
# Asia - Asia - 13172233958268439049
# , - , - 2593208677638477497
# lying - lie - 4613777942946297274
# along - along - 3962502770901397382
# the - the - 7425985699627899538
# southern - southern - 12121605977752639731
# slopes - slope - 8479741606164861403
# of - of - 886050111519832510
# the - the - 7425985699627899538
# Himalayan - himalayan - 12047400852052491985
# mountain - mountain - 3730195523052730522
# ranges - range - 9780120844974374175
# . - . - 12646065887601541794
# It - it - 10239237003504588839
# is - be - 10382539506755952630
# a - a - 11901859001352538922
# landlocked - landlocked - 14503696639117140888
# country - country - 12290671265767728302
# located - locate - 11779366343639771912
# between - between - 7508752285157982505
# India - India - 13756031414435721121
# to - to - 3791531372978436496
# ...

# %%
word=nlp(paragraph)
for x in word:
  print(x, "-",x.pos_,"-",spacy.explain(x.pos_),"-", x.tag_,spacy.explain(x.tag_))
# Out:
# Nepal - PROPN - proper noun - NNP noun, proper singular
# , - PUNCT - punctuation - , punctuation mark, comma
# country - NOUN - noun - NN noun, singular or mass
# of - ADP - adposition - IN conjunction, subordinating or preposition
# Asia - PROPN - proper noun - NNP noun, proper singular
# , - PUNCT - punctuation - , punctuation mark, comma
# lying - VERB - verb - VBG verb, gerund or present participle
# along - ADP - adposition - IN conjunction, subordinating or preposition
# the - DET - determiner - DT determiner
# southern - ADJ - adjective - JJ adjective (English), other noun-modifier (Chinese)
# slopes - NOUN - noun - NNS noun, plural
# of - ADP - adposition - IN conjunction, subordinating or preposition
# the - DET - determiner - DT determiner
# Himalayan - ADJ - adjective - JJ adjective (English), other noun-modifier (Chinese)
# mountain - NOUN - noun - NN noun, singular or mass
# ranges - NOUN - noun - NNS noun, plural
# ...

# %%
#printing except aux, adv and punct
for x in word:
  if x.pos_ not in ["AUX","ADV","PUNCT"]:
    print(x, "-",x.pos_,"-",spacy.explain(x.pos_),"-", x.tag_,spacy.explain(x.tag_))
# Out:
# Nepal - PROPN - proper noun - NNP noun, proper singular
# country - NOUN - noun - NN noun, singular or mass
# of - ADP - adposition - IN conjunction, subordinating or preposition
# Asia - PROPN - proper noun - NNP noun, proper singular
# lying - VERB - verb - VBG verb, gerund or present participle
# along - ADP - adposition - IN conjunction, subordinating or preposition
# the - DET - determiner - DT determiner
# southern - ADJ - adjective - JJ adjective (English), other noun-modifier (Chinese)
# slopes - NOUN - noun - NNS noun, plural
# of - ADP - adposition - IN conjunction, subordinating or preposition
# the - DET - determiner - DT determiner
# Himalayan - ADJ - adjective - JJ adjective (English), other noun-modifier (Chinese)
# mountain - NOUN - noun - NN noun, singular or mass
# ranges - NOUN - noun - NNS noun, plural
# It - PRON - pronoun - PRP pronoun, personal
# a - DET - determiner - DT determiner
# ...

# %%
stop_words=set(stopwords.words("english"))

# %%
print(stop_words)
# Out:
# {"couldn't", "weren't", 'themselves', 'on', 'wasn', "should've", 'each', 'weren', 'same', 'a', 'hasn', 'them', 'hers', "doesn't", 'these', 'mightn', 'or', 'over', "mightn't", 'herself', 'that', 'most', 'few', 'up', "won't", 'can', "didn't", "haven't", "you're", 'all', 'from', 'off', 'its', 'about', 'needn', 'is', 'out', 'under', 'ours', 'too', 'll', 'the', 'against', 'y', 'so', "wouldn't", 'my', "don't", 've', 'haven', 'shan', 'this', 'those', "you've", 'being', 'did', 'as', 'your', 'where', 'having', 'very', 'wouldn', 'why', 'after', 'her', 'below', 'me', "wasn't", "it's", 'only', 'above', 'when', 'own', 'have', 'while', 'doesn', 'they', 'our', 'through', 'will', 'then', 'again', 'theirs', 'to', 'no', 'do', "aren't", 'what', 'been', 'won', 'himself', 'by', "you'll", 'has', "hasn't", 's', 'and', 'at', 'here', "mustn't", 'some', 'doing', 'how', 'was', 'mustn', "that'll", 'nor', 'be', 'd', 'she', 'into', 'now', 'couldn', 'whom', 'just', 'didn', 'both', 'ain', 'of', 'isn', 'not', 'for',
# ...

# %%
filtered_sentence=[]
for w in words:
  if w not in stop_words:
    filtered_sentence.append(w)

print(filtered_sentence)
# Out:
# ['A', 'factor', 'contributes', 'immensely', 'geopolitical', 'importance', 'country', 'fact', 'strong', 'Nepal', 'deny', 'China', 'access', 'rich', 'Gangetic', 'Plain', ';', 'Nepal', 'thus', 'marks', 'southern', 'boundary', 'Chinese', 'sphere', 'north', 'Himalayas', 'Asia', '.']
